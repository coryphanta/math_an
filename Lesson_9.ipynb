# %% [markdown]
# ### Исследовать функцию на условный экстремум

# %% [markdown]
# 1. $U = 3 - 8x + 6y$ если $x^2 + y^2 = 36$

# %% [markdown]
# $L(x,y,\lambda)=3 - 8x + 6y +\lambda \cdot (x^2 + y^2 - 36)$ Составили функцию Лагранжа

# %% [markdown]
# Ищем частные производные и приравниваем их к нулю
#
# $$
# \left\{
#     \begin{array}\\
#         L'_{x}=-8 + 2\cdot\lambda x=0, \\
#         L'_{y}=6 + \lambda \cdot2y=0, \\
#         L'_{\lambda}=x^2+y^2-36=0
#     \end{array}
# \right.
# $$

# %% [markdown]
# Выражаем х, у, потом вычисляем все через $L'\lambda$

# %% [markdown]
# $
# \left\{
#     \begin{array}\\
#         x=\frac{4}{\lambda}, \\
#         y=-\frac{3}{\lambda}, \\
#         \left(\frac{4}{\lambda}\right)^2+\left(-\frac{3}{\lambda}\right)^2=36
#     \end{array}
# \right.
# $
# $\Rightarrow$
# $
# \left\{
#     \begin{array}\\
#         x=\frac{4}{\lambda}, \\
#         y=-\frac{3}{\lambda}, \\
#         \frac{25}{\lambda^2}=25
#     \end{array}
# \right.
# $
# $\Rightarrow$
# $
# \left\{
#     \begin{array}\\
#         x=\frac{4}{\lambda}, \\
#         y=-\frac{3}{\lambda}, \\
#         \lambda^2=\frac{25}{36}
#     \end{array}
# \right.
# $
# $\Rightarrow$
# $
# \left\{
#     \begin{array}\\
#         x_1=\frac{4 \cdot 6}{5} = \frac{24}{5}, \\
#         y_1=-\frac{3 \cdot 6}{5} = - \frac{18}{5}, \\
#         \lambda_1=\frac{5}{6}
#     \end{array}
# \right.
# $
# $;$
# $
# \left\{
#     \begin{array}\\
#         x_2=-\frac{4 \cdot 6}{5} = -\frac{24}{5}, \\
#         y_2=\frac{3 \cdot 6}{5} = \frac{18}{5}, \\
#         \lambda_2=-\frac{5}{6}
#     \end{array}
# \right.
# $

# %% [markdown]
# Нашли следующие точки:
# $(\frac{24}{5},- \frac{18}{5},\frac{5}{6})$ и $(-\frac{24}{5},\frac{18}{5},-\frac{5}{6})$

# %% [markdown]
# Ищем производные 2 порядка

# %% [markdown]
# $L''_{xx}=2\lambda$    $L''_{yy}=2\lambda$    $L''_{\lambda \lambda}=0$

# %% [markdown]
# $L''_{xy}=L''_{yx}=0$ $L''_{x\lambda}=L''_{\lambda x}=2x$ $L''_{y\lambda}=L''_{\lambda y}=2y$

# %% [markdown]
# Составляем матрицу, считаем определитель

# %% [markdown]
# $
# \large\begin{pmatrix}
#    L''_{\lambda\lambda} & L''_{\lambda x} & \large L''_{\lambda y} \\
#    L''_{x\lambda} & L''_{xx} & \large L''_{xy} \\
#    L''_{y\lambda} & L''_{yx} & \large L''_{yy}
# \end{pmatrix}
# $
# $
#  \Rightarrow
# $
# $
# \large\begin{pmatrix}
#    0 & 2x & 2y \\
#    2x & 2\lambda & 0 \\
#    2y & 0 & 2\lambda
# \end{pmatrix}
# $

# %% [markdown]
# $
# \begin{vmatrix}
#     0 & 2x & 2y \\
#     2x & 2\lambda & 0 \\
#     2y & 0 & 2\lambda
# \end{vmatrix}
# $
# $=$
# $(0\cdot2\lambda\cdot2\lambda+0\cdot2x\cdot2y+0\cdot2x\cdot2y)-(2y\cdot2y\cdot2\lambda+2x\cdot2x\cdot2\lambda+0\cdot0\cdot0)$
# $$\Delta=-8\lambda(x^2+y^2)$$

# %% [markdown]
# Так как $𝑥^2+𝑦^2=36$ то
# $\Delta=-8\lambda \cdot 36 = -288\lambda$

# %% [markdown]
# Для $(\frac{24}{5},- \frac{18}{5},\frac{5}{6})$  $\Delta < 0$, значит, это точка минимума
#
# Для $(-\frac{24}{5},\frac{18}{5},-\frac{5}{6})$  $\Delta > 0$, значит, это точка максимума
