# %% [markdown]
# ### 1. Найти неопределенный интеграл:

# %% [markdown]
# $\int (2x^2 - 2x - 1 + sinx - cosx + lnx + e^x)\, dx$

# %% [markdown]
# Избавляеимся от скобок и разложим интервал
# $$\$\int (2x^2 - 2x - 1 + sinx - cosx + lnx + e^x)\, dx = 2\int x^2 \, dx -  2\int x\, dx -\\- \int \,dx + \int sinx\, dx - \int cosx\, dx + \int lnx\, dx + \int e^x\, dx $$

# %% [markdown]
# Bыносим 2 из интеграла т.к. это константа и упрощаем

# %% [markdown]
# $$\frac{2x^3}{3} - \frac{2x^2}{2} - x - cosx - sinx + xlnx - \int x\cdot \frac{1}{x}\,dx + e^x + C $$

# %% [markdown]
# $$\frac{2x^3}{3} - x^2 - 2x - cosx - sinx + xlnx + e^x + C$$

# %% [markdown]
# ### 2. Найти неопределенный интеграл:

# %% [markdown]
# $$\int\left(2 x+6 x z^{2}-5 x^{2} y-3 \ln z\right) d x$$

# %% [markdown]
# Избавимся от скобок и разложим интервал

# %% [markdown]
# $$\int (2x + 6xz^2 - 5x^2y - 3lnz)\, dx$$

# %% [markdown]
# Bыносим 2 из интеграла т.к. это константа и упрощаем

# %% [markdown]
# $$ 2\int x\,dx + 6z^2\int x\,dx - 5y\int x^2\,dx - 3lnz\int \,dx = \\ = \frac{2x^2}{2} + 6z^2\frac{x^2}{2} - 5y\frac{x^3}{3} - 3xlnz + C = \\ = x^2 + 3z^2x^2 - 5y\frac{x^3}{3} - 3xlnz + C $$

# %% [markdown]
# Вычислить определенный интеграл:

# %% [markdown]
# $$\int_{0}^{\pi} 3 x^{2} \sin (2 x) d x$$

# %% [markdown]
# 3 - константа. Выносим наружу.

# %% [markdown]
# $$\int 3 x^{2} \sin (2 x) d x = - \frac{3}{2}\int x^{2} d \cos (2 x) $$

# %% [markdown]
#  Упрощаем

# %% [markdown]
# $$ - \frac{3}{2} x^{2} \cos (2 x) + \frac{3}{2}\int (x^{2})' \cos (2 x) dx = - \frac{3}{2} x^{2} \cos (2 x) + \frac{3}{2} \int x d \sin (2 x) $$

# %% [markdown]
# $$ = - \frac{3\pi^2}{2} + \frac{3}{4} - \frac{3}{4} = - \frac{3\pi^2}{2}$$

# %% [markdown]
# ### 4.Найти неопределенный интеграл:

# %% [markdown]
# $$\int \frac{1}{\sqrt{x+1}} d x$$

# %% [markdown]
# $$\int \frac{1}{\sqrt{x+1}} d x=\int \frac{1}{\sqrt{x+1}} d(x+1)=\int \frac{1}{\sqrt{x+1}} d \sqrt{x+1} ^2=\int \frac{1}{\sqrt{x+1}} 2 \sqrt{x+1} d \sqrt{x+1}=\int 2 d \sqrt{x+1}=2 \sqrt{x+1}+C$$
