# %% [markdown]
# ### №1. Найти длину 𝑥 и ширину 𝑦 прямоугольника при заданном периметре 𝑃=144 cм, при которых данный прямоугольник имеет наибольшую площадь 𝑆.

# %% [markdown]
# Составляем модель:
#
# Пусть одна стороны прямоугольника = x, тогда вторая = $\frac{1}{2}P - x = 72-x$
# В таком случае площадь S будет вычисляться слудующим образом:
# $$S = x\cdot(72-x) = 72x - x^2$$
#
# Ищем производную S'
#
# $S' = (72x - x^2)' = 72 - 2x$ Дифференцируем как степень по $nx^{n-1}$
#
# Ищем критические точки
#
# $$72 - 2x = 0$$
# $$ -2x = -72$$ Упрощаем делением на -2 обе стороны
# $$ x = 36 $$
# $$36 - максимум функции$$
# ПОлучаем 2 интервала $\left(-\infty,36 \right)$ и $\left(36, \infty \right)$
# $$f'(0) = 72-2\cdot0 = 72$$     0 $\in \left(-\infty,36 \right)$
# $$f'(37) = 72 - 2\cdot37 = -2$$  $37\in \left(36, \infty \right)$
#
# Вычислим S
#
# $$S = 72\cdot36 - 36^2 = 1296$$
#
# Найдем другую сторону прямоугольника
# $$72 - 36 = 36$$
#
# Вывод:
#
# Периметр = 144 см <br>
# Наибольшая площадь = $1296 см^2$ <br>
# Стороны = 36см x 36см

# %% [markdown]
# #### №2. найти экстремумы функций (если они есть)

# %% [markdown]
# 1) $$y = |2x|$$

# %% [markdown]
# Дифференцируем сложную функцию
# $$y' = \frac{2x}{|2x|}2x = \frac{4x}{|2x|}x $$
# дифференцируем х как степенную фунцию
# $$\frac{4x}{|2x|}1x^{1-1} = \frac{2x}{|x|}$$
# приравниваем проивзводную к 0
# $$2x = 0$$
# $$x= \frac{0}{2}= 0$$
# Значения нет, при котором $\frac{2x}{|x|} = 0$, экстремумов нет

# %% [markdown]
# 2) $$y=x^3$$

# %% [markdown]
# получаем производную 1 порядка ($nx^{n-1}$)
#
# $$y' = 3x^2$$
# Приравниваем к нулю для определения экстремума $$3x^2 = 0$$
# избавляемся от константы $$\frac{3x^2}{3} = \frac{0}{3}$$
# $$x^2 = 0$$
# избавляемся от степени $$x = \sqrt{0} = 0$$

# %% [markdown]
# x = 0 - критическая точка.
# Подставляем числа < 0 и > 0 в полученную производную
# $$3\cdot(-1)^2 = 3$$
# $$3\cdot1^2 = 3$$
# Знак не меняется вокруг 0, эстремумов нет

# %% [markdown]
# 3) $$y = e^{3x}$$ (или то же самое, что $$еxp(3x)$$)

# %% [markdown]
# Найдем производную, $(e^u)' = e^u \cdot u'$
# $$y' = (e^{3x})' = e^{3x} \cdot (3x)'$$
# Дифференцируем $3x$ с помощью $nx^{n-1}$
# $$e^{3x} \cdot (3 \cdot x^0) = 3e^{3x}$$
# Приравниваем к 0
# $$3e^{3x} = 0$$
# Решения нет, экстремумов нет

# %% [markdown]
# 4) $$y=x^3-5x$$

# %% [markdown]
# Производная по правилу сложения, степени убираем с помощью $$nx^{n-1}$$
# $$y' = (x^3 - 5x)' = 3x^2 + (-5x)' = 3x^2 - 5 \cdot 1 = 3x^2 - 5$$
# Ищем x, упрощаем делением обеих частей на 3:
# $$3x^2 = 5 => x^2 = \frac{5}{3} => x = \pm \sqrt\frac{5}{3} => x = \pm \frac{\sqrt{5}{\sqrt{3}} \cdot \frac{\sqrt{3}}{\sqrt{3}}} => x = \pm \frac{\sqrt{15}}{3}$$
# Точка максимума $\frac{\sqrt{15}}{3}$ ТОчка минимума $-\frac{\sqrt{15}}{3}$

# %% [markdown]
# Получаем интервалы:
# $$\left( -\infty, -\frac{\sqrt{15}}{3} \right); \left( -\frac{\sqrt{15}}{3},  \frac{\sqrt{15}}{3}\right); \left( \frac{\sqrt{15}}{3}, \infty \right);$$

# %% [markdown]
# подставляем входящие в эти интервалы -1, 0, 1
# $$f'(-2) = 3\cdot(-2)^2−5 = 7$$
# $$f'(0) = 3\cdot (0)^2-5 = -5$$
# $$f'(2) = 3\cdot (2)^2-5 = 7$$

# %% [markdown]
# Ищем экстремумы
# Заменяем x -> $-\frac{\sqrt{15}}{3}$ в функции
#
# $$\left( -\frac{\sqrt{15}}{3} \right)^3 - 5\left( -\frac{\sqrt{15}}{3} \right) = \frac{\sqrt{15^3}}{3^3} - 5\left( -\frac{\sqrt{15}}{3} \right) = \frac{\sqrt{15^2 \cdot 15}}{3^3} - 5\left( -\frac{\sqrt{15}}{3} \right) = \frac{15\sqrt{15^2}}{27} - 5\left( -\frac{\sqrt{15}}{3} \right) = \frac{5\sqrt{15}}{9} - 5\left( -\frac{\sqrt{15}}{3} \right) = \frac{5\sqrt{15}}{9} + \frac{5\sqrt{15}}{3} = \frac{5\sqrt{15}}{9} + \frac{5 \cdot 3\sqrt{15}}{3 \cdot 3} = \frac{5\sqrt{15} + 15\sqrt{15}}{9} = \frac{10\sqrt{15}}{9}$$

# %% [markdown]
# Считаем для $x = \frac{\sqrt{15}}{3}$

# %% [markdown]
# Получаем точки экстремумов:
# $$\left( -\frac{\sqrt{15}}{3},  \frac{10\sqrt{15}}{9} \right);  \left( \frac{\sqrt{15}}{3},  -\frac{10\sqrt{15}}{9} \right)$$
